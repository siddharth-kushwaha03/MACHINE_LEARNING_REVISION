# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Age": [20, 21, np.nan, 23, 24, 21, np.nan, 25],
    "Salary": [25000, 30000, np.nan, 35000, 40000, 30000, np.nan, 45000],
    "Experience": [1, 2, 1, np.nan, 4, 2, np.nan, 5],
    "City": ["Lucknow", "Delhi", "Lucknow", np.nan, "Delhi", "Delhi", "Lucknow", "Mumbai"],
    "Gender": ["Male", "Female", "Male", "Female", np.nan, "Female", "Male", "Female"],
    "Purchased": ["No", "Yes", "No", "Yes", "Yes", "No", "Yes", "Yes"]
})

df
# Out:
#     Age   Salary  Experience     City  Gender Purchased
# 0  20.0  25000.0         1.0  Lucknow    Male        No
# 1  21.0  30000.0         2.0    Delhi  Female       Yes
# 2   NaN      NaN         1.0  Lucknow    Male        No
# 3  23.0  35000.0         NaN      NaN  Female       Yes
# 4  24.0  40000.0         4.0    Delhi     NaN       Yes
# 5  21.0  30000.0         2.0    Delhi  Female        No
# 6   NaN      NaN         NaN  Lucknow    Male       Yes
# 7  25.0  45000.0         5.0   Mumbai  Female       Yes

# %% [markdown]
# ## 🟢 Level 1 — Missing Values

# %% [markdown]
# Q1-Check karo ki har column mein kitne missing values hain.

# %%
df.isnull().sum()
# Out:
# Age           2
# Salary        2
# Experience    2
# City          1
# Gender        1
# Purchased     0
# dtype: int64

# %% [markdown]
# Q2.Age ke missing values ko mean se fill karo.
